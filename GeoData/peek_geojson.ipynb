# %% [markdown]
# # Peek the Geo json File

# %%
import os
import json
# import urllib
import numpy as np
import geopandas as gpd
import pandas as pd
from urllib.request import urlopen

# %% [markdown]
# ## The Geo data is downloaded from aliyun
#
# Thanks the website of [https://geo.datav.aliyun.com/areas_v2]

# %%
local_dir = 'C:\\Sync\\GeoData'

def full_url(adcode):
    # Make full URL of the [adcode]
    json_name = f'{adcode}_full.json'
    return f'https://geo.datav.aliyun.com/areas_v2/bound/{json_name}'

def fetch_adcode(adcode=100000):
    # Request on the website for fetching the geojson of [adcode]
    url = full_url(adcode)
    
    local = os.path.join(local_dir, os.path.basename(url))
    if os.path.isfile(local):
        print(f'Found file in {local}')
        return json.load(open(local))
    
    with urlopen(url) as response:
        print(f'Requiring json from {url}')
        obj = json.load(response)
        with open(local, 'w') as f:
            json.dump(obj, f)
        return obj

def parse_features(geojson):
    # Parse features section in [geojson],
    # it supports to be the Geo features
    features = gpd.GeoDataFrame.from_features(geojson['features'])
    features = pd.DataFrame(features)
    features['geometry'] = '--'
    return features

# %% [markdown]
# ## Building a quick-to-check DataFrame of Chinese Geo Data
# The DataFrame of main_df will store the features of every avaiable provinces, cities and districts in China.
#
# The DataFrame will start from the collection of provinces, and iteratively being filled based on the features.

# %%
geojson = fetch_adcode()
main_df = parse_features(geojson)
main_df
# Out:
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/100000_full.json
#    geometry  adcode      name                   center  \
# 0        --  110000       北京市  [116.405285, 39.904989]
# 1        --  120000       天津市  [117.190182, 39.125596]
# 2        --  130000       河北省  [114.502461, 38.045474]
# 3        --  140000       山西省  [112.549248, 37.857014]
# 4        --  150000    内蒙古自治区  [111.670801, 40.818311]
# 5        --  210000       辽宁省  [123.429096, 41.796767]
# 6        --  220000       吉林省    [125.3245, 43.886841]
# 7        --  230000      黑龙江省  [126.642464, 45.756967]
# 8        --  310000       上海市  [121.472644, 31.231706]
# 9        --  320000       江苏省  [118.767413, 32.041544]
# 10       --  330000       浙江省  [120.153576, 30.287459]
# 11       --  340000       安徽省   [117.283042, 31.86119]
# 12       --  350000       福建省  [119.306239, 26.075302]
# 13       --  360000       江西省  [115.892151, 28.676493]
# 14       --  370000       山东省  [117.000923, 36.675807]
# 15       --  410000       河南省  [113.665412, 34.757975]
# 16       --  420000       湖北省  [114.298572, 30.584355]
# 17       --  430000       湖南省   [112.982279, 28.19409]
# 18       --  440000       广东省  [113.280637, 23.125178]
# 19       --  450000   广西壮族自治区   [108.320004, 22.82402]
# 20       --  460000       海南省   [110.33119, 20.031971]
# 21       --  500000       重庆市  [106.504962, 29.533155]
# 22       --  510000       四川省  [104.065735, 30.659462]
# 23       --  520000       贵州省  [106.713478, 26.578343]
# 24       --  530000       云南省  [102.712251, 25.040609]
# 25       --  540000     西藏自治区   [91.132212, 29.660361]
# 26       --  610000       陕西省  [108.948024, 34.263161]
# 27       --  620000       甘肃省  [103.823557, 36.058039]
# 28       --  630000       青海省  [101.778916, 36.623178]
# 29       --  640000   宁夏回族自治区   [106.278179, 38.46637]
# 30       --  650000  新疆维吾尔自治区   [87.617733, 43.792818]
# 31       --  710000       台湾省  [121.509062, 25.044332]
# 16             16.0  [100000]    NaN
# 17             17.0  [100000]    NaN
# 18             18.0  [100000]    NaN
# 19             19.0  [100000]    NaN
# 20             20.0  [100000]    NaN
# 21             21.0  [100000]    NaN
# 22             22.0  [100000]    NaN
# 23             23.0  [100000]    NaN
# 24             24.0  [100000]    NaN
# 25             25.0  [100000]    NaN
# 26             26.0  [100000]    NaN
# 27             27.0  [100000]    NaN
# 28             28.0  [100000]    NaN
# 29             29.0  [100000]    NaN
# 30             30.0  [100000]    NaN
# 31             31.0  [100000]    NaN
# 32             32.0  [100000]    NaN
# 33             33.0  [100000]    NaN
# 34              NaN       NaN     JD

# %%
geojson = fetch_adcode()
main_df = parse_features(geojson)

known_adcodes = set()
while len(main_df) > len(known_adcodes):
    for i in range(len(main_df)):
        se = main_df.iloc[i]
        adcode = se['adcode']

        if adcode in known_adcodes:
            continue
        known_adcodes.add(adcode)

        if se['childrenNum'] > 0:
            main_df = pd.concat([main_df, parse_features(fetch_adcode(adcode))], axis=0)

    main_df.index = range(len(main_df))

main_df.to_json(os.path.join(local_dir, 'main.json'))
main_df
# Out:
# Found file in C:\Sync\GeoData\100000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/110000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/120000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/310000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/460000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/500000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/630000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/650000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/810000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/820000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/130900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/131000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/131100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/140900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/141000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/141100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/150900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/152200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/152500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/152900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/210900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/211000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/211100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/211200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/211300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/211400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/220800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/222400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/230900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/231000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/231100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/231200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/232700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/320900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/321000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/321100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/321200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/321300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/330900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/331000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/331100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/340800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/341800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/350900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/360900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/361000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/361100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/370900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/371700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/410900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/411700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/420900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/421000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/421100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/421200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/421300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/422800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/430900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/431000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/431100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/431200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/431300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/433100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/440900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/441800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/445100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/445200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/445300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/450900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/451000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/451100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/451200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/451300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/451400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/460100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/460200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/460300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/510900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/511900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/512000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/513200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/513300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/513400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/520600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/522300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/522600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/522700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/530900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/532300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/532500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/532600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/532800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/532900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/533100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/533300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/533400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/540600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/542500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/610900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/611000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/620900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/621000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/621100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/621200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/622900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/623000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/630100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/630200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632600_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/632800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/640500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/650100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/650200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/650400_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/650500_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/652300_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/652700_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/652800_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/652900_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/653000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/653100_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/653200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/654000_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/654200_full.json
# Requiring json from https://geo.datav.aliyun.com/areas_v2/bound/654300_full.json
#      geometry  adcode    name                   center  \
# 0          --  110000     北京市  [116.405285, 39.904989]
# 1          --  120000     天津市  [117.190182, 39.125596]
# 2          --  130000     河北省  [114.502461, 38.045474]
# 3          --  140000     山西省  [112.549248, 37.857014]
# 4          --  150000  内蒙古自治区  [111.670801, 40.818311]
# ...       ...     ...     ...                      ...
# 3236       --  654322     富蕴县   [89.524993, 46.993106]
# 3237       --  654323     福海县   [87.494569, 47.113128]
# 3238       --  654324    哈巴河县   [86.418964, 48.059284]
# 3239       --  654325     青河县   [90.381561, 46.672446]
# 3240       --  654326    吉木乃县   [85.876064, 47.434633]
#
#                      centroid  childrenNum     level              parent  \
# 0       [116.41995, 40.18994]         16.0  province  {'adcode': 100000}
# 1      [117.347019, 39.28803]         16.0  province  {'adcode': 100000}
# 2                         NaN         11.0  province  {'adcode': 100000}
# 3     [112.304761, 37.618555]         11.0  province  {'adcode': 100000}
# 4     [114.077404, 44.331072]         12.0  province  {'adcode': 100000}
# ...                       ...          ...       ...                 ...
# 3236   [89.386618, 46.532364]          0.0  district  {'adcode': 654300}
# 3237   [88.046601, 46.362515]          0.0  district  {'adcode': 654300}
# 3238   [86.402485, 48.310203]          0.0  district  {'adcode': 654300}
# 3239    [90.39768, 46.263028]          0.0  district  {'adcode': 654300}
# 3240   [86.200562, 47.399536]          0.0  district  {'adcode': 654300}
#
#       subFeatureIndex                  acroutes adchar
# 0                 0.0                  [100000]    NaN
# 1                 1.0                  [100000]    NaN
# 2                 2.0                  [100000]    NaN
# 3                 3.0                  [100000]    NaN
# 4                 4.0                  [100000]    NaN
# ...               ...                       ...    ...
# 3236              2.0  [100000, 650000, 654300]    NaN
# 3237              3.0  [100000, 650000, 654300]    NaN
# 3238              4.0  [100000, 650000, 654300]    NaN
# 3239              5.0  [100000, 650000, 654300]    NaN
# 3240              6.0  [100000, 650000, 654300]    NaN
#
# [3241 rows x 11 columns]

# %%
# main_df['adcode'] = main_df.adcode.map(str)
# main_df = main_df.sort_values(by='adcode')
# main_df

# %%
df = pd.read_json(os.path.join(local_dir, 'main.json'))
df
# Out:
#      geometry  adcode    name                   center  \
# 0          --  110000     北京市  [116.405285, 39.904989]
# 1          --  120000     天津市  [117.190182, 39.125596]
# 2          --  130000     河北省  [114.502461, 38.045474]
# 3          --  140000     山西省  [112.549248, 37.857014]
# 4          --  150000  内蒙古自治区  [111.670801, 40.818311]
# ...       ...     ...     ...                      ...
# 3236       --  654322     富蕴县   [89.524993, 46.993106]
# 3237       --  654323     福海县   [87.494569, 47.113128]
# 3238       --  654324    哈巴河县   [86.418964, 48.059284]
# 3239       --  654325     青河县   [90.381561, 46.672446]
# 3240       --  654326    吉木乃县   [85.876064, 47.434633]
#
#                      centroid  childrenNum     level              parent  \
# 0       [116.41995, 40.18994]         16.0  province  {'adcode': 100000}
# 1      [117.347019, 39.28803]         16.0  province  {'adcode': 100000}
# 2                        None         11.0  province  {'adcode': 100000}
# 3     [112.304761, 37.618555]         11.0  province  {'adcode': 100000}
# 4     [114.077404, 44.331072]         12.0  province  {'adcode': 100000}
# ...                       ...          ...       ...                 ...
# 3236   [89.386618, 46.532364]          0.0  district  {'adcode': 654300}
# 3237   [88.046601, 46.362515]          0.0  district  {'adcode': 654300}
# 3238   [86.402485, 48.310203]          0.0  district  {'adcode': 654300}
# 3239    [90.39768, 46.263028]          0.0  district  {'adcode': 654300}
# 3240   [86.200562, 47.399536]          0.0  district  {'adcode': 654300}
#
#       subFeatureIndex                  acroutes adchar
# 0                 0.0                  [100000]   None
# 1                 1.0                  [100000]   None
# 2                 2.0                  [100000]   None
# 3                 3.0                  [100000]   None
# 4                 4.0                  [100000]   None
# ...               ...                       ...    ...
# 3236              2.0  [100000, 650000, 654300]   None
# 3237              3.0  [100000, 650000, 654300]   None
# 3238              4.0  [100000, 650000, 654300]   None
# 3239              5.0  [100000, 650000, 654300]   None
# 3240              6.0  [100000, 650000, 654300]   None
#
# [3241 rows x 11 columns]
